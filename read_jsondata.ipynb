# %%
import json

# Open the JSON file
with open('OutputNucleiAnot.json', 'r') as json_file:
    data = json.load(json_file)

# 'data' now contains the content of the JSON file as a Python dictionary or list, depending on the JSON structure
print(data)
# Out:
# {'_accessLevel': 2, '_id': '64d141c3fbf1f5cbcd39f0ab', '_modelType': 'annotation', '_version': 1247, 'annotation': {'elements': [{'type': 'polyline', 'points': [[1663.0, 570.0, 0.0], [1663.0, 574.0, 0.0], [1663.0, 576.0, 0.0], [1661.0, 576.0, 0.0], [1661.0, 577.0, 0.0], [1659.0, 577.0, 0.0], [1659.0, 578.0, 0.0], [1658.0, 578.0, 0.0], [1658.0, 579.0, 0.0], [1656.0, 579.0, 0.0], [1654.0, 579.0, 0.0], [1654.0, 578.0, 0.0], [1653.0, 578.0, 0.0], [1653.0, 576.0, 0.0], [1652.0, 576.0, 0.0], [1652.0, 574.0, 0.0], [1653.0, 574.0, 0.0], [1653.0, 572.0, 0.0], [1654.0, 572.0, 0.0], [1654.0, 570.0, 0.0]], 'closed': True, 'fillColor': 'rgba(0,0,0,0)', 'lineColor': 'rgb(0,255,0)', 'id': '64d14043fbf1f5cbcd39ee02'}, {'type': 'polyline', 'points': [[1442.0, 577.0, 0.0], [1442.0, 578.0, 0.0], [1444.0, 578.0, 0.0], [1444.0, 580.0, 0.0], [1445.0, 580.0, 0.0], [1445.0, 582.0, 0.0], [1446.0, 582.0, 0.0], [1446.0, 583.0, 0.0], [1448.0, 583.0, 0.0], [1448.0, 584.0, 0.0], [1450.0, 584.0, 0.0], [1452.0, 584
# ...

# %%
len(data['annotation']['elements'])
# Out:
# 327

# %%
import pandas as pd
df = pd.read_csv('nucleiF-1.csv')
#df = df.drop(df.index[-1])
df

# # Save the DataFrame to a CSV file
# clustered_data_filename = 'nucleiF-1.csv'
# df.to_csv(clustered_data_filename, index=False)
# Out:
#      Feature.Label  Feature.Identifier.Xmin  Feature.Identifier.Ymin  \
# 0              1.0                    328.0                      0.0
# 1              2.0                    113.0                      7.0
# 2              3.0                    486.0                     12.0
# 3              4.0                    435.0                     19.0
# 4              5.0                    687.0                      0.0
# ..             ...                      ...                      ...
# 322           84.0                    317.0                    560.0
# 323           85.0                     77.0                    560.0
# 324           86.0                     47.0                    563.0
# 325           87.0                    366.0                    586.0
# 326           88.0                    581.0                    584.0
#
#      Feature.Identifier.Xmax  Feature.Identifier.Ymax  \
# 0                      341.0                     11.0
# ...

# %%
# Out:
# array([[1.00000000e+00, 3.28000000e+02, 0.00000000e+00, ...,
#         5.72056695e-02, 6.70770873e-01, 1.37822602e-01],
#        [2.00000000e+00, 1.13000000e+02, 7.00000000e+00, ...,
#         8.86511559e-02, 6.72146925e-01, 2.04951755e-01],
#        [3.00000000e+00, 4.86000000e+02, 1.20000000e+01, ...,
#         5.05762285e-02, 6.00789721e-01, 1.53679569e-01],
#        ...,
#        [8.60000000e+01, 4.70000000e+01, 5.63000000e+02, ...,
#         7.13522985e-02, 5.31223763e-01, 2.74781852e-01],
#        [8.70000000e+01, 3.66000000e+02, 5.86000000e+02, ...,
#         7.63480745e-02, 6.74094645e-01, 1.88990906e-01],
#        [8.80000000e+01, 5.81000000e+02, 5.84000000e+02, ...,
#         8.17284508e-02, 6.55704208e-01, 2.18049349e-01]])
